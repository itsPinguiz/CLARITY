# %%
import os
import sys
from google.colab import drive

# 1. Monta Google Drive
drive.mount('/content/drive')

# Definisci il percorso permanente sul TUO Drive
DRIVE_WORKSPACE = "/content/drive/MyDrive/progettoLLM"
REPO_DIR = f"{DRIVE_WORKSPACE}/CLARITY"

# 2. Crea la cartella base se non esiste
os.makedirs(DRIVE_WORKSPACE, exist_ok=True)
os.chdir(DRIVE_WORKSPACE)

# 3. Clona o aggiorna la repo
if not os.path.exists(REPO_DIR):
    print("Clonazione del repository per la prima volta...")
    # !git clone https://github.com/itsPinguiz/CLARITY
else:
    print("Repository già presente su Drive. Aggiornamento in corso...")
    # !cd {REPO_DIR} && git pull origin main

# 4. Spostati dentro la repo e aggiungila al path di Python
os.chdir(REPO_DIR)
if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)

# 5. Lancia lo script di setup
print("Avvio dello script di setup di CLARITY...")
# !bash setup.sh

print("Setup Completato! L'ambiente è pronto.")
